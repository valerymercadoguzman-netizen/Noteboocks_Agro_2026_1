# %% [markdown]
# <a href="https://colab.research.google.com/github/valerymercadoguzman-netizen/Noteboocks_Agro_2026_1/blob/main/Notebook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA: Emtra ancho y alto de la madera en metros
ancho = input("Ingresa el ancho de la ventana en metros")
ancho = float(ancho)
alto = input("Ingresa el alto de la ventana en metros")
alto = float(alto)

# PROCESO: Calcula longitud de la manera (lm) en pies
# y el area del vidrio en metros cuadrados
lm = 2  * (ancho + alto) * 3.25
av = 2 * (ancho + alto)

# SALIDA: Sale la longitud de la madera en pies
# el area del vidrio en metros cuadrados
print("Longitud de la madera es" , lm, " pies de longitud")
print("El area de vidrio es" , av, " metros cuadrados")
# Out:
# Ingresa el ancho de la ventana en metros1
# Ingresa el alto de la ventana en metros2
# Longitud de la madera es 19.5  pies de longitud
# El area de vidrio es 6.0  metros cuadrados
